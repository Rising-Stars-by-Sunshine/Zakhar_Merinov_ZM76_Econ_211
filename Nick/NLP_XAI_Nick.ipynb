# %% [markdown]
# # Part 0: Set-up

# %%
pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
pip install igviz
# Out:
# Requirement already satisfied: igviz in /usr/local/lib/python3.10/dist-packages (0.5.1)
# Requirement already satisfied: ipywidgets>=7.7.1 in /usr/local/lib/python3.10/dist-packages (from igviz) (7.7.1)
# Requirement already satisfied: networkx>=2.8.5 in /usr/local/lib/python3.10/dist-packages (from igviz) (3.2)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from igviz) (5.15.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->igviz) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->igviz) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->igviz) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->igviz) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->igviz) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7.1->igviz) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->igviz) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->igviz) (23.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.7.1->igviz) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.7.1->igviz) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (5.4.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.7.1->igviz) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.7.1->igviz) (0.2.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (4.19.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.7.1->igviz) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7.1->igviz) (2.21)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Rising-Stars-by-Sunshine/Econ211-Week2.github.io/main/Nick/literature.csv")
df = df[['Title', 'Abstract']]
df
# Out:
#                                                Title  \
# 0      Explainable AI for Credit Assessment in Banks
# 1     Google Cloud Platform: Bigquery Explainable AI
# 2  Explainable AI: A brief survey on history, res...
#
#                                             Abstract
# 0  Banks’ credit scoring models are required by f...
# 1  Machine-learning (ML) models have become a com...
# 2  Deep learning has made significant contributio...

# %% [markdown]
# # Part I The World Cloud

# %% [markdown]
# ## 1.1. Title

# %%
# Join the different processed titles together.
title = ','.join(list(df['Title'].values))
title
# Out:
# 'Explainable AI for Credit Assessment in Banks,Google Cloud Platform: Bigquery Explainable AI,Explainable AI: A brief survey on history, research areas, approaches and challenges'

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stop_words = stopwords.words('english')
stop_words.extend([',',"SoK","survey",":","A","on","in","into","the","for","review",])
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", ',', 'SoK', 'survey', ':', 'A', 'on', 'in', 'into', 'the', 'for', 'review']

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
wordcloud = WordCloud(width= 300, height = 200, random_state=1, background_color='#3D9140', colormap='Pastel2', collocations=False, stopwords =stop_words).generate(title)

# show the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %%
wordcloud = WordCloud(width= 300, height = 200, random_state=1, background_color='#0066CC', colormap='Pastel2', collocations=False, stopwords =stop_words).generate(title)

# Show the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %% [markdown]
# ## 1.2. Abstract

# %%
# Join the different processed titles together.
Abstract = ','.join(list(df['Abstract'].values))
Abstract
# Out:
# "Banks’ credit scoring models are required by financial authorities to be explainable. This paper proposes an explainable artificial intelligence (XAI) model for predicting credit default on a unique dataset of unsecured consumer loans provided by a Norwegian bank. We combined a LightGBM model with SHAP, which enables the interpretation of explanatory variables affecting the predictions. The LightGBM model clearly outperforms the bank’s actual credit scoring model (Logistic Regression). We found that the most important explanatory variables for predicting default in the LightGBM model are the volatility of utilized credit balance, remaining credit in percentage of total credit and the duration of the customer relationship. Our main contribution is the implementation of XAI methods in banking, exploring how these methods can be applied to improve the interpretability and reliability of state-of-the-art AI models. We also suggest a method for analyzing the potential economic value of an improved credit scoring model.,Machine-learning (ML) models have become a common tool used across a multitude of industries to help people make decisions. As these models have increased in predictive power, many have also grown in complexity. The pursuit to improve the accuracy of predictions has diminished the interpretability of many models—leaving users with little understanding of the model's behavior or trust in its predictions. The field of eXplainable artificial intelligence (XAI) seeks to encourage the development of interpretable models. Google Cloud Platform offers two Explainable AI functions in BigQuery ML that allow users to examine the attribution of model features, which aids in model behavior verification and bias recognition. One of the functions available in BigQuery provides a global perspective on the features used to train the model, while the second function examines local feature attribution associated with individual predictions in more detail. This note offers an overview of Explainable AI in BigQuery ML, using as an example a (fictional) realtor's linear regression model that predicted a home's latest sale price based on predictor variables such as the total tax assessment from the year of the last sale, the square footage of the house, the number of bedrooms, the number of bathrooms, and whether the condition of the home is below average. After training the linear model, the feature attribution can be studied from a global and local perspective in BigQuery.,Deep learning has made significant contribution to the recent progress in artificial intelligence. In comparison to traditional machine learning methods such as decision trees and support vector machines, deep learning methods have achieved substantial improvement in various prediction tasks. However, deep neural networks (DNNs) are comparably weak in explaining their inference processes and final results, and they are typically treated as a black-box by both developers and users. Some people even consider DNNs (deep neural networks) in the current stage rather as\xa0alchemy, than as real science. In many real-world applications such as business decision, process optimization, medical diagnosis and investment recommendation, explainability and transparency of our AI systems become particularly essential for their users, for the people who are affected by AI decisions, and furthermore, for the researchers and developers who create the AI solutions. In recent years, the explainability and explainable AI have received increasing attention by both research community and industry. This paper first introduces the history of Explainable AI, starting from expert systems and traditional machine learning approaches to the latest progress in the context of modern deep learning, and then describes the major research areas and the state-of-art approaches in recent years. The paper ends with a discussion on the challenges and future directions."

# %%
stop_words = stopwords.words('english')
stop_words.extend(['.'])
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", '.']

# %%
wordcloud = WordCloud(width= 300, height = 200, random_state=1, background_color='#3D9140', colormap='Pastel2', collocations=False, stopwords =stop_words).generate(Abstract)

# show the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %%
wordcloud = WordCloud(width= 300, height = 200, random_state=1, background_color='#0066CC', colormap='Pastel2', collocations=False, stopwords =stop_words).generate(Abstract)

# Show the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %% [markdown]
# # Part II Bigram

# %% [markdown]
# ## 2.1. Title

# %%
df.columns
# Out:
# Index(['Title', 'Abstract'], dtype='object')

# %%
import regex
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
df_Title  = df['Title'].str.lower()

# %%
Titles = ('. '.join(list(df_Title.values)))
Titles = regex.sub(r'\b[0-9]+\b\W*', '', Titles)
Titles = regex.sub(r'(?:^| )\w(?:$| )', ' ', Titles)
Titles =Titles.replace(":"," ")
Titles =Titles.replace("."," ")
Titles =Titles.replace("?"," ")
Titles =Titles.replace("("," ")
Titles =Titles.replace(")"," ")
Titles
# Out:
# 'explainable ai for credit assessment in banks  google cloud platform  bigquery explainable ai  explainable ai  brief survey on history, research areas, approaches and challenges'

# %%
def remove_url(txt):
    url_pattern = regex.compile(r'https?://\S+|www\.\S+')
    no_url = url_pattern.sub(r'', txt)

    return no_url


def stem_tokens(tokens):
    stemmer = nltk.stem.PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens


def lemmatize_tokens(tokens):
    lemmatizer = nltk.stem.WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return tokens

# %%
text_no_urls = remove_url(Titles)
text_no_urls = text_no_urls.encode('utf-8', errors='ignore').decode('utf-8')
words_in_text = text_no_urls.split()

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '.']

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
import string
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
lemmatizer = WordNetLemmatizer()
words_nsw= [lemmatizer.lemmatize(w) for w in words_in_text]
words_nsw = [
    word for word in words_nsw if word not in string.punctuation]
words_nsw
# Out:
# ['explainable',
#  'ai',
#  'for',
#  'credit',
#  'assessment',
#  'in',
#  'bank',
#  'google',
#  'cloud',
#  'platform',
#  'bigquery',
#  'explainable',
#  'ai',
#  'explainable',
#  'ai',
#  'brief',
#  'survey',
#  'on',
#  'history,',
#  'research',
#  'areas,',
#  'approach',
#  'and',
#  'challenge']

# %%
stop_words = stopwords.words('english')
stop_words.extend([',','survey',':','A','on','in','into','the','for','review','.','SOK:','Sok:','(sok).'])
words_nsw = [word for word in words_nsw if not word in stop_words]
words_nsw = [ele for ele in words_nsw if len(ele) < 20]
words_nsw = [word for word in words_nsw if not word in ['An','SOK','How','sok']]
words_nsw
# Out:
# ['explainable',
#  'ai',
#  'credit',
#  'assessment',
#  'bank',
#  'google',
#  'cloud',
#  'platform',
#  'bigquery',
#  'explainable',
#  'ai',
#  'explainable',
#  'ai',
#  'brief',
#  'history,',
#  'research',
#  'areas,',
#  'approach',
#  'challenge']

# %%
import collections

# %%
bigram = list(nltk.bigrams(words_nsw))
bigram_counts = collections.Counter(bigram).most_common(100)

# %%
title_bigram=pd.DataFrame(bigram_counts)
title_bigram.columns = ['bigram', 'counts']
title_bigram = title_bigram.sort_values(by=['counts'], ascending=False)
title_bigram.head(20)
# Out:
#                      bigram  counts
# 0         (explainable, ai)       3
# 1              (ai, credit)       1
# 2      (credit, assessment)       1
# 3        (assessment, bank)       1
# 4            (bank, google)       1
# 5           (google, cloud)       1
# 6         (cloud, platform)       1
# 7      (platform, bigquery)       1
# 8   (bigquery, explainable)       1
# 9         (ai, explainable)       1
# 10              (ai, brief)       1
# 11        (brief, history,)       1
# 12     (history,, research)       1
# 13       (research, areas,)       1
# 14       (areas,, approach)       1
# 15    (approach, challenge)       1

# %%
print(title_bigram.head(25).to_latex(index=False))
# Out:
# \begin{tabular}{lr}
# \toprule
#                  bigram &  counts \\
# \midrule
#       (explainable, ai) &       3 \\
#            (ai, credit) &       1 \\
#    (credit, assessment) &       1 \\
#      (assessment, bank) &       1 \\
#          (bank, google) &       1 \\
#         (google, cloud) &       1 \\
#       (cloud, platform) &       1 \\
#    (platform, bigquery) &       1 \\
# (bigquery, explainable) &       1 \\
#       (ai, explainable) &       1 \\
#             (ai, brief) &       1 \\
#       (brief, history,) &       1 \\
#    (history,, research) &       1 \\
#      (research, areas,) &       1 \\
#      (areas,, approach) &       1 \\
#   (approach, challenge) &       1 \\
# \bottomrule
# \end{tabular}
# <ipython-input-38-d48c86c5ce71>:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(title_bigram.head(25).to_latex(index=False))

# %%
print(title_bigram.head(25).to_markdown(index=False))
# Out:
# | bigram                      |   counts |
# |:----------------------------|---------:|
# | ('explainable', 'ai')       |        3 |
# | ('ai', 'credit')            |        1 |
# | ('credit', 'assessment')    |        1 |
# | ('assessment', 'bank')      |        1 |
# | ('bank', 'google')          |        1 |
# | ('google', 'cloud')         |        1 |
# | ('cloud', 'platform')       |        1 |
# | ('platform', 'bigquery')    |        1 |
# | ('bigquery', 'explainable') |        1 |
# | ('ai', 'explainable')       |        1 |
# | ('ai', 'brief')             |        1 |
# | ('brief', 'history,')       |        1 |
# | ('history,', 'research')    |        1 |
# | ('research', 'areas,')      |        1 |
# | ('areas,', 'approach')      |        1 |
# | ('approach', 'challenge')   |        1 |

# %%
title_bigram.to_csv("title_bigram.csv")

# %%
import networkx as nx

# %%
G = nx.Graph()
for edge in bigram_counts:
    link = edge[0]
    count = edge[1]

    G.add_edge(link[0], link[1], weight=count)

# %%
# Create dictionary of bigrams and their counts
d = title_bigram.set_index('bigram').T.to_dict('records')
# Create network plot
G = nx.Graph()
# Create connections between nodes
for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=v/10000)
G.remove_nodes_from(["pfv", "tag"])

# %%
G = nx.Graph()
for edge in bigram_counts:
    link = edge[0]
    count = edge[1]

    G.add_edge(link[0], link[1], weight=count)

# %%
fig, ax = plt.subplots(figsize=(20, 20))

pos = nx.spring_layout(G, k=10)
edgewidth = [d['weight'] for (u,v,d) in G.edges(data=True)]


# Plot networks
nx.draw_networkx(G, pos,
                 font_size=10,
                 width=edgewidth,
                 edge_color='green',
                 node_color='green',
                 with_labels = False,
                 ax=ax)
plt.grid(None)
# Create offset labels
for key, value in pos.items():
    x, y = value[0]+0.035, value[1]+0.045
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='green', alpha=0.15),
            horizontalalignment='center', fontsize=12)
plt.show()

# %%
import igviz as ig

# %%
import os

new_path = "figures/title_bigram.html"
os.makedirs(os.path.dirname(new_path), exist_ok=True)

# %%
fig = ig.plot(
    G,
    node_opacity=0.8,
)
fig.update_layout(
    dict(
        width=800,
        height=600,
    )
)

with open('figures/title_bigram.html', 'w') as f:
    f.write(fig.to_html())

fig.show()
fig.write_html("figures/title_bigram.html")
# Out:
# <ipython-input-48-360256bff3c0>:1: DeprecationWarning: Argument `titlefont_size` is deprecated and will be removed in 0.6.0.
#   fig = ig.plot(
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="349fba22-f93c-4dc8-8421-ee55673ab65c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("349fba22-f93c-4dc8-8421-ee55673ab65c")) {                    Plotly.newPlot(                        "349fba22-f93c-4dc8-8421-ee55673ab65c",                        [{"hoverinfo":"text","line":{"color":"#888","width":1},"mode":"lines","text":[],"x":[0.6926912069320679,0.13881859183311462,null,0.6926912069320679,0.6270062923431396,null,0.13881859183311462,0.6206533312797546,null,0.13881859183311462,0.35872775316238403,null,0.6206533312797546,0.04627523943781853,null,0.04627523943781853,0.8269741535186768,null,0.8269741535186768,0.8092252612113953,null,0.8092252612113953,0.14989954233169556,null,0.14989954233169556,0.951484739780426,null,0.951484739780426,0.6270062923431396,null,0.35872775316238403,0.6868120431900024,null,0.6868120431900024,0.5648989677429199,null,0.5648989677429199,0.9725027084350586,null,0.9725027084350586,0.08706660568714142,null,0.08706660568714142,0.8670133352279663,null],"y":[0.7688996195793152,0.20936080813407898,null,0.7688996195793152,0.47671014070510864,null,0.20936080813407898,0.7890043258666992,null,0.20936080813407898,0.7782277464866638,null,0.7890043258666992,0.5601990222930908,null,0.5601990222930908,0.6194732189178467,null,0.6194732189178467,0.8736392259597778,null,0.8736392259597778,0.07644511759281158,null,0.07644511759281158,0.7257339954376221,null,0.7257339954376221,0.47671014070510864,null,0.7782277464866638,0.3942423462867737,null,0.3942423462867737,0.8506162166595459,null,0.8506162166595459,0.988507866859436,null,0.988507866859436,0.3251512050628662,null,0.3251512050628662,0.29984113574028015,null],"type":"scatter","uid":"5932e57d-15ef-4075-a6ac-bb3b50d029c6"},{"hoverinfo":"text","hovertext":["Node: explainable\u003cbr\u003eDegree: 2","Node: ai\u003cbr\u003eDegree: 3","Node: credit\u003cbr\u003eDegree: 2","Node: assessment\u003cbr\u003eDegree: 2","Node: bank\u003cbr\u003eDegree: 2","Node: google\u003cbr\u003eDegree: 2","Node: cloud\u003cbr\u003eDegree: 2","Node: platform\u003cbr\u003eDegree: 2","Node: bigquery\u003cbr\u003eDegree: 2","Node: brief\u003cbr\u003eDegree: 2","Node: history,\u003cbr\u003eDegree: 2","Node: research\u003cbr\u003eDegree: 2","Node: areas,\u003cbr\u003eDegree: 2","Node: approach\u003cbr\u003eDegree: 2","Node: challenge\u003cbr\u003eDegree: 1"],"marker":{"color":[2,3,2,2,2,2,2,2,2,2,2,2,2,2,1],"colorbar":{"thickness":15,"title":{"side":"right"},"xanchor":"left"},"colorscale":[[0.0,"rgb(255,255,217)"],[0.125,"rgb(237,248,177)"],[0.25,"rgb(199,233,180)"],[0.375,"rgb(127,205,187)"],[0.5,"rgb(65,182,196)"],[0.625,"rgb(29,145,192)"],[0.75,"rgb(34,94,168)"],[0.875,"rgb(37,52,148)"],[1.0,"rgb(8,29,88)"]],"line":{"width":0},"opacity":0.8,"reversescale":true,"showscale":true,"size":[14,15,14,14,14,14,14,14,14,14,14,14,14,14,13]},"mode":"markers","text":[],"textposition":"bottom center","x":[0.6926912069320679,0.13881859183311462,0.6206533312797546,0.04627523943781853,0.8269741535186768,0.8092252612113953,0.14989954233169556,0.951484739780426,0.6270062923431396,0.35872775316238403,0.6868120431900024,0.5648989677429199,0.9725027084350586,0.08706660568714142,0.8670133352279663],"y":[0.7688996195793152,0.20936080813407898,0.7890043258666992,0.5601990222930908,0.6194732189178467,0.8736392259597778,0.07644511759281158,0.7257339954376221,0.47671014070510864,0.7782277464866638,0.3942423462867737,0.8506162166595459,0.988507866859436,0.3251512050628662,0.29984113574028015],"type":"scatter","uid":"9e242c91-6cd3-4809-96f7-eea76b2679d3"},{"hoverinfo":"text","marker":{"opacity":0},"mode":"markers","text":[],"textposition":"middle center","x":[],"y":[],"type":"scatter","uid":"b946bbca-36bb-4707-928d- ...

# %% [markdown]
# ## 2.2. Abstract

# %%
df_Abstract = df['Abstract'].str.lower()

# %%
Abstract = ('. '.join(list(df_Abstract.values)))
Abstract = regex.sub(r'\b[0-9]+\b\W*', '', Abstract)
Abstract = regex.sub(r'(?:^| )\w(?:$| )', ' ', Abstract)
Abstract =Abstract.replace(":"," ")
Abstract =Abstract.replace("."," ")
Abstract =Abstract.replace("?"," ")
Abstract =Abstract.replace("("," ")
Abstract =Abstract.replace(")"," ")
Abstract =Abstract.replace('"'," ")
Abstract =Abstract.replace(','," ")
Abstract
# Out:
# "banks’ credit scoring models are required by financial authorities to be explainable  this paper proposes an explainable artificial intelligence  xai  model for predicting credit default on unique dataset of unsecured consumer loans provided by norwegian bank  we combined lightgbm model with shap  which enables the interpretation of explanatory variables affecting the predictions  the lightgbm model clearly outperforms the bank’s actual credit scoring model  logistic regression   we found that the most important explanatory variables for predicting default in the lightgbm model are the volatility of utilized credit balance  remaining credit in percentage of total credit and the duration of the customer relationship  our main contribution is the implementation of xai methods in banking  exploring how these methods can be applied to improve the interpretability and reliability of state-of-the-art ai models  we also suggest method for analyzing the potential economic value of an improved credit scoring model   machine-learning  ml  models have become common tool used across multitude of industries to help people make decisions  as these models have increased in predictive power  many have also grown in complexity  the pursuit to improve the accuracy of predictions has diminished the interpretability of many models—leaving users with little understanding of the model's behavior or trust in its predictions  the field of explainable artificial intelligence  xai  seeks to encourage the development of interpretable models  google cloud platform offers two explainable ai functions in bigquery ml that allow users to examine the attribution of model features  which aids in model behavior verification and bias recognition  one of the functions available in bigquery provides global perspective on the features used to train the model  while the second function examines local feature attribution associated with individual predictions in more detail  this note offers an overview of explainable ai in bigquery ml  using as an example  fictional  realtor's linear regression model that predicted home's latest sale price based on predictor variables such as the total tax assessment from the year of the last sale  the square footage of the house  the number of bedrooms  the number of bathrooms  and whether the condition of the home is below average  after training the linear model  the feature attribution can be studied from global and local perspective in bigquery   deep learning has made significant contribution to the recent progress in artificial intelligence  in comparison to traditional machine learning methods such as decision trees and support vector machines  deep learning methods have achieved substantial improvement in various prediction tasks  however  deep neural networks  dnns  are comparably weak in explaining their inference processes and final results  and they are typically treated as black-box by both developers and users  some people even consider dnns  deep neural networks  in the current stage rather as\xa0alchemy  than as real science  in many real-world applications such as business decision  process optimization  medical diagnosis and investment recommendation  explainability and transparency of our ai systems become particularly essential for their users  for the people who are affected by ai decisions  and furthermore  for the researchers and developers who create the ai solutions  in recent years  the explainability and explainable ai have received increasing attention by both research community and industry  this paper first introduces the history of explainable ai  starting from expert systems and traditional machine learning approaches to the latest progress in the context of modern deep learning  and then describes the major research areas and the state-of-art approaches in recent years  the paper ends with discussion on the challenges and future directions "

# %%
def remove_url(txt):
    url_pattern = regex.compile(r'https?://\S+|www\.\S+')
    no_url = url_pattern.sub(r'', txt)

    return no_url


def stem_tokens(tokens):
    stemmer = nltk.stem.PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens


def lemmatize_tokens(tokens):
    lemmatizer = nltk.stem.WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return tokens

# %%
text_no_urls = remove_url(Abstract)
text_no_urls = text_no_urls.encode('utf-8', errors='ignore').decode('utf-8')
words_in_text = text_no_urls.split()

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  ',',
#  'survey',
#  ':',
#  'A',
#  'on',
#  'in',
#  'into',
#  'the',
#  'for',
#  'review',
#  '.',
#  'SOK:',
#  'Sok:',
#  '(sok).']

# %%
lemmatizer = WordNetLemmatizer()
words_nsw= [lemmatizer.lemmatize(w) for w in words_in_text]
words_nsw = [
    word for word in words_nsw if word not in string.punctuation]
words_nsw
# Out:
# ['banks’',
#  'credit',
#  'scoring',
#  'model',
#  'are',
#  'required',
#  'by',
#  'financial',
#  'authority',
#  'to',
#  'be',
#  'explainable',
#  'this',
#  'paper',
#  'proposes',
#  'an',
#  'explainable',
#  'artificial',
#  'intelligence',
#  'xai',
#  'model',
#  'for',
#  'predicting',
#  'credit',
#  'default',
#  'on',
#  'unique',
#  'dataset',
#  'of',
#  'unsecured',
#  'consumer',
#  'loan',
#  'provided',
#  'by',
#  'norwegian',
#  'bank',
#  'we',
#  'combined',
#  'lightgbm',
#  'model',
#  'with',
#  'shap',
#  'which',
#  'enables',
#  'the',
#  'interpretation',
#  'of',
#  'explanatory',
#  'variable',
#  'affecting',
#  'the',
#  'prediction',
#  'the',
#  'lightgbm',
#  'model',
#  'clearly',
#  'outperforms',
#  'the',
#  'bank’s',
#  'actual',
#  'credit',
#  'scoring',
#  'model',
#  'logistic',
#  'regression',
#  'we',
#  'found',
#  'that',
#  'the',
#  'most',
#  'important',
#  'explanatory',
#  'variable',
#  'for',
#  'predicting',
#  'default',
#  'in',
#  'the',
#  'lightgbm',
#  'model',
#  'are',
#  'the',
#  'volatility',
#  'of',
#  'utilized',
#  'credit',
#  'balance',
#  'remaining',
#  'credit',
#  'in',
#  'percentage',
#  'of',
#  'total',
#  'credit',
#  'and',
#  'the',
#  'duration',
#  'of',
#  'the',
#  'customer',
#  'relationship',
#  'our',
#  'main',
#  'contribution',
#  'is',
#  'the',
#  'implementation',
#  'of',
#  'xai',
#  'method',
#  'in',
#  'banking',
#  'exploring',
#  'how',
#  'these',
#  'method',
#  'can',
#  'be',
#  'applied',
#  'to',
#  'improve',
#  'the',
#  'interpretability',
#  'and',
#  'reliability',
#  'of',
#  'state-of-the-art',
#  'ai',
#  'model',
#  'we',
#  'also',
#  'suggest',
#  'method',
#  'for',
#  'analyzing',
#  'the',
#  'potential',
#  'economic',
#  'value',
#  'of',
#  'an',
#  'improved',
#  'credit',
#  'scoring',
#  'model',
#  'machine-learning',
#  'ml',
#  'model',
#  'have',
#  'become',
#  'common',
#  'tool',
#  'used',
#  'across',
#  'multitude',
#  'of',
#  'industry',
#  'to',
#  'help',
#  'people',
#  'make',
#  'decision',
#  'a',
#  'these',
#  'model',
#  'have',
#  'increased',
#  'in',
#  'predictive',
#  'power',
#  'many',
#  'have',
#  'also',
#  'grown',
#  'in',
#  'complexity',
#  'the',
#  'pursuit',
#  'to',
#  'improve',
#  'the',
#  'accuracy',
#  'of',
#  'prediction',
#  'ha',
#  'diminished',
#  'the',
#  'interpretability',
#  'of',
#  'many',
#  'models—leaving',
#  'user',
#  'with',
#  'little',
#  'understanding',
#  'of',
#  'the',
#  "model's",
#  'behavior',
#  'or',
#  'trust',
#  'in',
#  'it',
#  'prediction',
#  'the',
#  'field',
#  'of',
#  'explainable',
#  'artificial',
#  'intelligence',
#  'xai',
#  'seek',
#  'to',
#  'encourage',
#  'the',
#  'development',
#  'of',
#  'interpretable',
#  'model',
#  'google',
#  'cloud',
#  'platform',
#  'offer',
#  'two',
#  'explainable',
#  'ai',
#  'function',
#  'in',
#  'bigquery',
#  'ml',
#  'that',
#  'allow',
#  'user',
#  'to',
#  'examine',
#  'the',
#  'attribution',
#  'of',
#  'model',
#  'feature',
#  'which',
#  'aid',
#  'in',
#  'model',
#  'behavior',
#  'verification',
#  'and',
#  'bias',
#  'recognition',
#  'one',
#  'of',
#  'the',
#  'function',
#  'available',
#  'in',
#  'bigquery',
#  'provides',
#  'global',
#  'perspective',
#  'on',
#  'the',
#  'feature',
#  'used',
#  'to',
#  'train',
#  'the',
#  'model',
#  'while',
#  'the',
#  'second',
#  'function',
#  'examines',
#  'local',
#  'feature',
#  'attribution',
#  'associated',
#  'with',
#  'individual',
#  'prediction',
#  'in',
#  'more',
#  'detail',
#  'this',
#  'note',
#  'offer',
#  'an',
#  'overview',
#  'of',
#  'explainable',
#  'ai',
#  'in',
#  'bigquery',
#  'ml',
#  'using',
#  'a',
#  'an',
#  'example',
#  'fictional',
#  "realtor's",
#  'linear',
#  'regression',
#  'model',
#  'that',
#  'predicted',
#  "home's",
#  'latest',
#  'sale',
#  'price',
#  'based',
#  'on',
#  'predictor',
#  'variable',
#  'such',
#  'a',
#  'the',
#  'total',
#  'tax',
#  'assessment',
#  'from',
#  'the',
#  'year',
#  'of',
#  'the',
#  'last',
#  'sale',
#  'the',
#  'square',
#  'footage',
#  'of',
#  'the',
#  'house',
#  'the',
#  'number',
#  'of',
#  'bedroom',
#  'the',
#  'number',
#  'of',
#  'bathroom',
#  'and',
#  'whether',
#  'the',
#  'condition',
#  'of',
#  'the',
#  'home',
#  'is',
#  'below',
#  'average',
#  'after',
#  'training',
#  'the',
#  'linear',
#  'model',
#  'the',
#  'feature',
#  'attribution',
#  'can',
#  'be',
#  'studied',
#  'from',
#  'global',
#  'and',
#  'local',
#  'perspective',
#  'in',
#  'bigquery',
#  'deep',
#  'learning',
#  'ha',
#  'made',
#  'significant',
#  'contribution',
#  'to',
#  'the',
#  'recent',
#  'progress',
#  'in',
#  'artificial',
#  'intelligence',
#  'in',
#  'comparison',
#  'to',
#  'traditional',
#  'machine',
#  'learning',
#  'method',
#  'such',
#  'a',
#  'decision',
#  'tree',
#  'and',
#  'support',
#  'vector',
#  'machine',
#  'deep',
#  'learning',
#  'method',
#  'have',
#  'achieved',
#  'substantial',
#  'improvement',
#  'in',
#  'various',
#  'prediction',
#  'task',
#  'however',
#  'deep',
#  'neural',
#  'network',
#  'dnns',
#  'are',
#  'comparably',
#  'weak',
#  'in',
#  'explaining',
#  'their',
#  'inference',
#  'process',
#  'and',
#  'final',
#  'result',
#  'and',
#  'they',
#  'are',
#  'typically',
#  'treated',
#  'a',
#  'black-box',
#  'by',
#  'both',
#  'developer',
#  'and',
#  'user',
#  'some',
#  'people',
#  'even',
#  'consider',
#  'dnns',
#  'deep',
#  'neural',
#  'network',
#  'in',
#  'the',
#  'current',
#  'stage',
#  'rather',
#  'a',
#  'alchemy',
#  'than',
#  'a',
#  'real',
#  'science',
#  'in',
#  'many',
#  'real-world',
#  'application',
#  'such',
#  'a',
#  'business',
#  'decision',
#  'process',
#  'optimization',
#  'medical',
#  'diagnosis',
#  'and',
#  'investment',
#  'recommendation',
#  'explainability',
#  'and',
#  'transparency',
#  'of',
#  'our',
#  'ai',
#  'system',
#  'become',
#  'particularly',
#  'essential',
#  'for',
#  'their',
#  'user',
#  'for',
#  'the',
#  'people',
#  'who',
#  'are',
#  'affected',
#  'by',
#  'ai',
#  'decision',
#  'and',
#  'furthermore',
#  'for',
#  'the',
#  'researcher',
#  'and',
#  'developer',
#  'who',
#  'create',
#  'the',
#  'ai',
#  'solution',
#  'in',
#  'recent',
#  'year',
#  'the',
#  'explainability',
#  'and',
#  'explainable',
#  'ai',
#  'have',
#  'received',
#  'increasing',
#  'attention',
#  'by',
#  'both',
#  'research',
#  'community',
#  'and',
#  'industry',
#  'this',
#  'paper',
#  'first',
#  'introduces',
#  'the',
#  'history',
#  'of',
#  'explainable',
#  'ai',
#  'starting',
#  'from',
#  'expert',
#  'system',
#  'and',
#  'traditional',
#  'machine',
#  'learning',
#  'approach',
#  'to',
#  'the',
#  'latest',
#  'progress',
#  'in',
#  'the',
#  'context',
#  'of',
#  'modern',
#  'deep',
#  'learning',
#  'and',
#  'then',
#  'describes',
#  'the',
#  'major',
#  'research',
#  'area',
#  'and',
#  'the',
#  'state-of-art',
#  'approach',
#  'in',
#  'recent',
#  'year',
#  'the',
#  'paper',
#  'end',
#  'with',
#  'discussion',
#  'on',
#  'the',
#  'challenge',
#  'and',
#  'future',
#  'direction']

# %%
stop_words = stopwords.words('english')
stop_words.extend([',','survey',':','A','on','in','into','the','for','review','.','SOK:','Sok:','(sok).'])
words_nsw = [word for word in words_nsw if not word in stop_words]
words_nsw = [ele for ele in words_nsw if len(ele) < 20]
words_nsw = [word for word in words_nsw if not word in ['An','SOK','How','sok','e','g','drb','ha']]
words_nsw
# Out:
# ['banks’',
#  'credit',
#  'scoring',
#  'model',
#  'required',
#  'financial',
#  'authority',
#  'explainable',
#  'paper',
#  'proposes',
#  'explainable',
#  'artificial',
#  'intelligence',
#  'xai',
#  'model',
#  'predicting',
#  'credit',
#  'default',
#  'unique',
#  'dataset',
#  'unsecured',
#  'consumer',
#  'loan',
#  'provided',
#  'norwegian',
#  'bank',
#  'combined',
#  'lightgbm',
#  'model',
#  'shap',
#  'enables',
#  'interpretation',
#  'explanatory',
#  'variable',
#  'affecting',
#  'prediction',
#  'lightgbm',
#  'model',
#  'clearly',
#  'outperforms',
#  'bank’s',
#  'actual',
#  'credit',
#  'scoring',
#  'model',
#  'logistic',
#  'regression',
#  'found',
#  'important',
#  'explanatory',
#  'variable',
#  'predicting',
#  'default',
#  'lightgbm',
#  'model',
#  'volatility',
#  'utilized',
#  'credit',
#  'balance',
#  'remaining',
#  'credit',
#  'percentage',
#  'total',
#  'credit',
#  'duration',
#  'customer',
#  'relationship',
#  'main',
#  'contribution',
#  'implementation',
#  'xai',
#  'method',
#  'banking',
#  'exploring',
#  'method',
#  'applied',
#  'improve',
#  'interpretability',
#  'reliability',
#  'state-of-the-art',
#  'ai',
#  'model',
#  'also',
#  'suggest',
#  'method',
#  'analyzing',
#  'potential',
#  'economic',
#  'value',
#  'improved',
#  'credit',
#  'scoring',
#  'model',
#  'machine-learning',
#  'ml',
#  'model',
#  'become',
#  'common',
#  'tool',
#  'used',
#  'across',
#  'multitude',
#  'industry',
#  'help',
#  'people',
#  'make',
#  'decision',
#  'model',
#  'increased',
#  'predictive',
#  'power',
#  'many',
#  'also',
#  'grown',
#  'complexity',
#  'pursuit',
#  'improve',
#  'accuracy',
#  'prediction',
#  'diminished',
#  'interpretability',
#  'many',
#  'models—leaving',
#  'user',
#  'little',
#  'understanding',
#  "model's",
#  'behavior',
#  'trust',
#  'prediction',
#  'field',
#  'explainable',
#  'artificial',
#  'intelligence',
#  'xai',
#  'seek',
#  'encourage',
#  'development',
#  'interpretable',
#  'model',
#  'google',
#  'cloud',
#  'platform',
#  'offer',
#  'two',
#  'explainable',
#  'ai',
#  'function',
#  'bigquery',
#  'ml',
#  'allow',
#  'user',
#  'examine',
#  'attribution',
#  'model',
#  'feature',
#  'aid',
#  'model',
#  'behavior',
#  'verification',
#  'bias',
#  'recognition',
#  'one',
#  'function',
#  'available',
#  'bigquery',
#  'provides',
#  'global',
#  'perspective',
#  'feature',
#  'used',
#  'train',
#  'model',
#  'second',
#  'function',
#  'examines',
#  'local',
#  'feature',
#  'attribution',
#  'associated',
#  'individual',
#  'prediction',
#  'detail',
#  'note',
#  'offer',
#  'overview',
#  'explainable',
#  'ai',
#  'bigquery',
#  'ml',
#  'using',
#  'example',
#  'fictional',
#  "realtor's",
#  'linear',
#  'regression',
#  'model',
#  'predicted',
#  "home's",
#  'latest',
#  'sale',
#  'price',
#  'based',
#  'predictor',
#  'variable',
#  'total',
#  'tax',
#  'assessment',
#  'year',
#  'last',
#  'sale',
#  'square',
#  'footage',
#  'house',
#  'number',
#  'bedroom',
#  'number',
#  'bathroom',
#  'whether',
#  'condition',
#  'home',
#  'average',
#  'training',
#  'linear',
#  'model',
#  'feature',
#  'attribution',
#  'studied',
#  'global',
#  'local',
#  'perspective',
#  'bigquery',
#  'deep',
#  'learning',
#  'made',
#  'significant',
#  'contribution',
#  'recent',
#  'progress',
#  'artificial',
#  'intelligence',
#  'comparison',
#  'traditional',
#  'machine',
#  'learning',
#  'method',
#  'decision',
#  'tree',
#  'support',
#  'vector',
#  'machine',
#  'deep',
#  'learning',
#  'method',
#  'achieved',
#  'substantial',
#  'improvement',
#  'various',
#  'prediction',
#  'task',
#  'however',
#  'deep',
#  'neural',
#  'network',
#  'dnns',
#  'comparably',
#  'weak',
#  'explaining',
#  'inference',
#  'process',
#  'final',
#  'result',
#  'typically',
#  'treated',
#  'black-box',
#  'developer',
#  'user',
#  'people',
#  'even',
#  'consider',
#  'dnns',
#  'deep',
#  'neural',
#  'network',
#  'current',
#  'stage',
#  'rather',
#  'alchemy',
#  'real',
#  'science',
#  'many',
#  'real-world',
#  'application',
#  'business',
#  'decision',
#  'process',
#  'optimization',
#  'medical',
#  'diagnosis',
#  'investment',
#  'recommendation',
#  'explainability',
#  'transparency',
#  'ai',
#  'system',
#  'become',
#  'particularly',
#  'essential',
#  'user',
#  'people',
#  'affected',
#  'ai',
#  'decision',
#  'furthermore',
#  'researcher',
#  'developer',
#  'create',
#  'ai',
#  'solution',
#  'recent',
#  'year',
#  'explainability',
#  'explainable',
#  'ai',
#  'received',
#  'increasing',
#  'attention',
#  'research',
#  'community',
#  'industry',
#  'paper',
#  'first',
#  'introduces',
#  'history',
#  'explainable',
#  'ai',
#  'starting',
#  'expert',
#  'system',
#  'traditional',
#  'machine',
#  'learning',
#  'approach',
#  'latest',
#  'progress',
#  'context',
#  'modern',
#  'deep',
#  'learning',
#  'describes',
#  'major',
#  'research',
#  'area',
#  'state-of-art',
#  'approach',
#  'recent',
#  'year',
#  'paper',
#  'end',
#  'discussion',
#  'challenge',
#  'future',
#  'direction']

# %%
bigram = list(nltk.bigrams(words_nsw))
bigram_counts = collections.Counter(bigram).most_common(100)

# %%
abstract_bigram=pd.DataFrame(bigram_counts)
abstract_bigram.columns = ['bigram', 'counts']
abstract_bigram = abstract_bigram.sort_values(by=['counts'], ascending=False)
abstract_bigram.head(25)
# Out:
#                             bigram  counts
# 0                (explainable, ai)       4
# 2                 (scoring, model)       3
# 3       (artificial, intelligence)       3
# 4                (lightgbm, model)       3
# 5                 (deep, learning)       3
# 1                (credit, scoring)       3
# 12          (traditional, machine)       2
# 18                  (recent, year)       2
# 17                  (user, people)       2
# 16               (neural, network)       2
# 15                  (deep, neural)       2
# 13             (machine, learning)       2
# 14              (learning, method)       2
# 11          (feature, attribution)       2
# 10                (model, feature)       2
# 9                   (bigquery, ml)       2
# 8          (explanatory, variable)       2
# 7              (intelligence, xai)       2
# 6        (explainable, artificial)       2
# 69                 (total, credit)       1
# 77                   (xai, method)       1
# 76           (implementation, xai)       1
# 75  (contribution, implementation)       1
# 74            (main, contribution)       1
# 73            (relationship, main)       1

# %%
print(abstract_bigram.head(90).to_latex(index=False))
# Out:
# \begin{tabular}{lr}
# \toprule
#                          bigram &  counts \\
# \midrule
#               (explainable, ai) &       4 \\
#                (scoring, model) &       3 \\
#      (artificial, intelligence) &       3 \\
#               (lightgbm, model) &       3 \\
#                (deep, learning) &       3 \\
#               (credit, scoring) &       3 \\
#          (traditional, machine) &       2 \\
#                  (recent, year) &       2 \\
#                  (user, people) &       2 \\
#               (neural, network) &       2 \\
#                  (deep, neural) &       2 \\
#             (machine, learning) &       2 \\
#              (learning, method) &       2 \\
#          (feature, attribution) &       2 \\
#                (model, feature) &       2 \\
#                  (bigquery, ml) &       2 \\
#         (explanatory, variable) &       2 \\
#             (intelligence, xai) &       2 \\
#       (explainable, artificial) &       2 \\
#                 (total, credit) &       1 \\
#                   (xai, method) &       1 \\
#           (implementation, xai) &       1 \\
#  (contribution, implementation) &       1 \\
#            (main, contribution) &       1 \\
#            (relationship, main) &       1 \\
#        (customer, relationship) &       1 \\
#            (duration, customer) &       1 \\
#              (credit, duration) &       1 \\
#             (model, volatility) &       1 \\
#             (percentage, total) &       1 \\
#            (credit, percentage) &       1 \\
#             (remaining, credit) &       1 \\
#            (balance, remaining) &       1 \\
#               (credit, balance) &       1 \\
#              (utilized, credit) &       1 \\
#          (volatility, utilized) &       1 \\
#            (banking, exploring) &       1 \\
#               (method, banking) &       1 \\
#                   (model, also) &       1 \\
#             (exploring, method) &       1 \\
#               (method, applied) &       1 \\
#          (machine-learning, ml) &       1 \\
#       (model, machine-learning) &       1 \\
#              (improved, credit) &       1 \\
#               (value, improved) &       1 \\
#               (economic, value) &       1 \\
#           (potential, economic) &       1 \\
#          (analyzing, potential) &       1 \\
#             (method, analyzing) &       1 \\
#               (suggest, method) &       1 \\
#                 (also, suggest) &       1 \\
#           (predicting, default) &       1 \\
#                     (ai, model) &       1 \\
#          (state-of-the-art, ai) &       1 \\
# (reliability, state-of-the-art) &       1 \\
# (interpretability, reliability) &       1 \\
#     (improve, interpretability) &       1 \\
#              (applied, improve) &       1 \\
#             (default, lightgbm) &       1 \\
#           (outperforms, bank’s) &       1 \\
#          (variable, predicting) &       1 \\
#        (important, explanatory) &       1 \\
#                (consumer, loan) &       1 \\
#           (unsecured, consumer) &       1 \\
#            (dataset, unsecured) &       1 \\
#               (unique, dataset) &       1 \\
#               (default, unique) &       1 \\
#               (credit, default) &       1 \\
#            (predicting, credit) &       1 \\
#             (model, predicting) &       1 \\
#                    (xai, model) &       1 \\
#         (proposes, explainable) &       1 \\
#               (paper, proposes) &       1 \\
#            (explainable, paper) &       1 \\
#        (authority, explainable) &       1 \\
#          (financial, authority) &       1 \\
#           (required, financial) &       1 \\
#               (model, required) &       1 \\
#                (banks’, credit) &       1 \\
#                (loan, provided) &       1 \\
#           (provided, norwegian) &       1 \\
#               (norwegian, bank) &       1 \\
#                (model, clearly) &       1 \\
#              (found, important) &       1 \\
#             (regression, found) &       1 \\
#          (logistic, regression) &       1 \\
#               (model, logistic) &       1 \\
#                (actual, credit) &       1 \\
#                (bank’s, actual) &       1 \\
#          (clearly, outperforms) &       1 \\
# \bottomrule
# \end{tabular}
# <ipython-input-58-84cfb0cbda73>:1: FutureWarning:
#
# In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.

# %%
print(abstract_bigram.head(25).to_markdown(index=False))
# Out:
# | bigram                             |   counts |
# |:-----------------------------------|---------:|
# | ('explainable', 'ai')              |        4 |
# | ('scoring', 'model')               |        3 |
# | ('artificial', 'intelligence')     |        3 |
# | ('lightgbm', 'model')              |        3 |
# | ('deep', 'learning')               |        3 |
# | ('credit', 'scoring')              |        3 |
# | ('traditional', 'machine')         |        2 |
# | ('recent', 'year')                 |        2 |
# | ('user', 'people')                 |        2 |
# | ('neural', 'network')              |        2 |
# | ('deep', 'neural')                 |        2 |
# | ('machine', 'learning')            |        2 |
# | ('learning', 'method')             |        2 |
# | ('feature', 'attribution')         |        2 |
# | ('model', 'feature')               |        2 |
# | ('bigquery', 'ml')                 |        2 |
# | ('explanatory', 'variable')        |        2 |
# | ('intelligence', 'xai')            |        2 |
# | ('explainable', 'artificial')      |        2 |
# | ('total', 'credit')                |        1 |
# | ('xai', 'method')                  |        1 |
# | ('implementation', 'xai')          |        1 |
# | ('contribution', 'implementation') |        1 |
# | ('main', 'contribution')           |        1 |
# | ('relationship', 'main')           |        1 |

# %%
abstract_bigram.to_csv("abstract_bigram.csv")

# %%
# Create dictionary of bigrams and their counts
d = abstract_bigram.set_index('bigram').T.to_dict('records')
# Create network plot
G = nx.Graph()
# Create connections between nodes
for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=v/10000)
G.remove_nodes_from(["pfv", "tag"])

# %%
G = nx.Graph()
for edge in bigram_counts:
    link = edge[0]
    count = edge[1]

    G.add_edge(link[0], link[1], weight=count/10)

# %%
fig, ax = plt.subplots(figsize=(20, 20))

pos = nx.spring_layout(G, k=10)
edgewidth = [d['weight'] for (u,v,d) in G.edges(data=True)]


# Plot networks
nx.draw_networkx(G, pos,
                 font_size=10,
                 width=edgewidth,
                 edge_color='blue',
                 node_color='blue',
                 with_labels = False,
                 ax=ax)
plt.grid(None)
# Create offset labels
for key, value in pos.items():
    x, y = value[0]+0.035, value[1]+0.045
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='blue', alpha=0.15),
            horizontalalignment='center', fontsize=11)

plt.show()

# %%
import os

new_path = "figures/Abstract_bigram.html"
os.makedirs(os.path.dirname(new_path), exist_ok=True)

# %%
fig = ig.plot(
    G,
    node_opacity=0.8,
)
fig.update_layout(
    dict(
        width=800,
        height=600,
    )
)

with open('figures/Abstract_bigram.html', 'w') as f:
    f.write(fig.to_html())

fig.show()
fig.write_html("figures/Abstract_bigram.html")
# Out:
# <ipython-input-65-017664b3c192>:1: DeprecationWarning:
#
# Argument `titlefont_size` is deprecated and will be removed in 0.6.0.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="321ee12b-55d5-4465-ad05-7c3e878dfc0a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("321ee12b-55d5-4465-ad05-7c3e878dfc0a")) {                    Plotly.newPlot(                        "321ee12b-55d5-4465-ad05-7c3e878dfc0a",                        [{"hoverinfo":"text","line":{"color":"#888","width":1},"mode":"lines","text":[],"x":[0.36426833271980286,0.973274827003479,null,0.36426833271980286,0.35694849491119385,null,0.36426833271980286,0.7242992520332336,null,0.36426833271980286,0.024488579481840134,null,0.36426833271980286,0.02968548983335495,null,0.973274827003479,0.759608268737793,null,0.973274827003479,0.11076027154922485,null,0.7801718711853027,0.7357672452926636,null,0.7801718711853027,0.9205571413040161,null,0.7801718711853027,0.237684965133667,null,0.7801718711853027,0.3150247037410736,null,0.7801718711853027,0.041993867605924606,null,0.7801718711853027,0.5668967962265015,null,0.7801718711853027,0.584472119808197,null,0.7801718711853027,0.5572811365127563,null,0.7801718711853027,0.9786983132362366,null,0.7801718711853027,0.9892364740371704,null,0.7801718711853027,0.27484405040740967,null,0.7801718711853027,0.9827212691307068,null,0.7357672452926636,0.11076027154922485,null,0.11076027154922485,0.8463326096534729,null,0.11076027154922485,0.0036626500077545643,null,0.11076027154922485,0.334223210811615,null,0.11076027154922485,0.08363518118858337,null,0.11076027154922485,0.237684965133667,null,0.11076027154922485,0.8609420657157898,null,0.11076027154922485,0.781029462814331,null,0.11076027154922485,0.5332608222961426,null,0.11076027154922485,0.07847265899181366,null,0.11076027154922485,0.6683200001716614,null,0.11076027154922485,0.7097626328468323,null,0.11076027154922485,0.15649591386318207,null,0.35694849491119385,0.4581072926521301,null,0.4581072926521301,0.08363518118858337,null,0.8463326096534729,0.3187372088432312,null,0.8463326096534729,0.6109777092933655,null,0.8463326096534729,0.3150247037410736,null,0.7834124565124512,0.43665212392807007,null,0.7834124565124512,0.48759281635284424,null,0.43665212392807007,0.12213661521673203,null,0.43665212392807007,0.08481632173061371,null,0.08363518118858337,0.4552333950996399,null,0.08363518118858337,0.08481632173061371,null,0.3118707537651062,0.2593151032924652,null,0.3118707537651062,0.18827272951602936,null,0.3118707537651062,0.8224694132804871,null,0.2593151032924652,0.7728873491287231,null,0.2593151032924652,0.237684965133667,null,0.2836116552352905,0.15649591386318207,null,0.15649591386318207,0.7097626328468323,null,0.0036626500077545643,0.6632651686668396,null,0.17309783399105072,0.12213661521673203,null,0.08481632173061371,0.4928663671016693,null,0.08481632173061371,0.18848077952861786,null,0.08481632173061371,0.08028723299503326,null,0.08481632173061371,0.09390578418970108,null,0.08481632173061371,0.5807231664657593,null,0.48759281635284424,0.303507000207901,null,0.5707306861877441,0.1969393491744995,null,0.15145640075206757,0.16339178383350372,null,0.334223210811615,0.36016058921813965,null,0.36016058921813965,0.7242992520332336,null,0.024488579481840134,0.02968548983335495,null,0.237684965133667,0.3150247037410736,null,0.3150247037410736,0.660189688205719,null,0.660189688205719,0.13016904890537262,null,0.13016904890537262,0.19837701320648193,null,0.19837701320648193,0.8047181963920593,null,0.8047181963920593,0.6080916523933411,null,0.6080916523933411,0.1482192724943161,null,0.1482192724943161,0.1523115634918213,null,0.1523115634918213,0.32976409792900085,null,0.32976409792900085,0.3187372088432312,null,0.8609420657157898,0.15944735705852509,null,0.15944735705852509,0.18827272951602936,null,0.7728873491287231,0.6109777092933655,null,0.781029462814331,0.67 ...
